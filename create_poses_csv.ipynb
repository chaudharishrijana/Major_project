# %%
import mediapipe as mp
import pandas as pd
import numpy as np
import cv2
import os

# %%
mp_pose = mp.solutions.pose

# %%
landmarks_points = {
    "nose": 0,
    "left_shoulder": 11, "right_shoulder": 12,
    "left_elbow": 13, "right_elbow": 14,
    "left_wrist": 15, "right_wrist": 16,
    "left_hip": 23, "right_hip": 24,
    "left_knee": 25, "right_knee": 26,
    "left_ankle": 27, "right_ankle": 28,
    "left_heel": 29, "right_heel": 30,
    "left_foot_index": 31, "right_foot_index": 32,
}

col_names = []
for i in range(len(landmarks_points.keys())):
    name = list(landmarks_points.keys())[i]
    col_names.append(name + "_x")
    col_names.append(name + "_y")
    col_names.append(name + "_z")
    col_names.append(name + "_v")

pose_name = col_names.copy()

pose_name.append("pose")

# %%
# List to store pose data
pose_list = []

# Main directory for images
main_dir = "./poses_dataset/Images"

# Get list of pose directories
pose_dir_list = os.listdir(main_dir)

# Process each directory and image
for i, pose_dir in enumerate(pose_dir_list):
    images_dir_list = os.listdir(f"{main_dir}/{pose_dir}")
    
    for l, image_file in enumerate(images_dir_list):
        pre_list = []
        image_path = f"{main_dir}/{pose_dir}/{image_file}"

        # Load image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue

        # Process image using MediaPipe Pose
        with mp_pose.Pose(static_image_mode=True, enable_segmentation=True) as pose:
            result = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

            if not result.pose_landmarks:
                print(f"No pose landmarks detected: {image_path}")
                continue
            
            # Extract landmarks
            for landmark in result.pose_landmarks.landmark:
                pre_list.append(landmark)

        # Extract specific landmarks and flatten the data
        try:
            gen1116 = np.array([
                [
                    pre_list[m].x,
                    pre_list[m].y,
                    pre_list[m].z,
                    pre_list[m].visibility
                ] for m in range(11, 17)
            ]).flatten().tolist()

            gen2333 = np.array([
                [
                    pre_list[m].x,
                    pre_list[m].y,
                    pre_list[m].z,
                    pre_list[m].visibility
                ] for m in range(23, 33)
            ]).flatten().tolist()

            gen1116.extend(gen2333)

            all_list = [
                pre_list[0].x,
                pre_list[0].y,
                pre_list[0].z,
                pre_list[0].visibility,
            ]
            all_list.extend(gen1116)

            # Append pose index and add to the list
            tpl = all_list.copy()
            tpl.append(i)
            pose_list.append(tpl)

        except IndexError:
            print(f"Incomplete pose landmarks for {image_path}")
            continue

# Save pose data to CSV
pose_name = [f"feature_{i}" for i in range(len(pose_list[0]) - 1)] + ["pose_label"]
data_pose = pd.DataFrame(pose_list, columns=pose_name)
data_pose.to_csv("./csv_files/poses_data_pose.csv", index=False)

print("Pose data successfully saved to './csv_files/poses_data_pose.csv'")
# Out:
# Failed to load image: ./poses_dataset/Images/Goddess/1.json
# Failed to load image: ./poses_dataset/Images/Goddess/10.json
# Failed to load image: ./poses_dataset/Images/Goddess/100.json
# Failed to load image: ./poses_dataset/Images/Goddess/101.json
# Failed to load image: ./poses_dataset/Images/Goddess/102.json
# Failed to load image: ./poses_dataset/Images/Goddess/103.json
# Failed to load image: ./poses_dataset/Images/Goddess/104.json
# Failed to load image: ./poses_dataset/Images/Goddess/105.json
# Failed to load image: ./poses_dataset/Images/Goddess/106.json
# Failed to load image: ./poses_dataset/Images/Goddess/107.json
# Failed to load image: ./poses_dataset/Images/Goddess/108.json
# Failed to load image: ./poses_dataset/Images/Goddess/109.json
# Failed to load image: ./poses_dataset/Images/Goddess/11.json
# Failed to load image: ./poses_dataset/Images/Goddess/110.json
# Failed to load image: ./poses_dataset/Images/Goddess/111.json
# Failed to load image: ./poses_dataset/Images/Goddess/112.json
# Failed to load image: ./poses_dataset/Images/Goddess/113.json
# Failed to load image: ./poses_dataset/Images/Goddess/114.json
# Failed to load image: ./poses_dataset/Images/Goddess/115.json
# Failed to load image: ./poses_dataset/Images/Goddess/116.json
# Failed to load image: ./poses_dataset/Images/Goddess/117.json
# Failed to load image: ./poses_dataset/Images/Goddess/118.json
# Failed to load image: ./poses_dataset/Images/Goddess/119.json
# Failed to load image: ./poses_dataset/Images/Goddess/12.json
# Failed to load image: ./poses_dataset/Images/Goddess/120.json
# Failed to load image: ./poses_dataset/Images/Goddess/121.json
# Failed to load image: ./poses_dataset/Images/Goddess/122.json
# Failed to load image: ./poses_dataset/Images/Goddess/123.json
# Failed to load image: ./poses_dataset/Images/Goddess/124.json
# Failed to load image: ./poses_dataset/Images/Goddess/125.json
# Failed to load image: ./poses_dataset/Images/Goddess/126.json
# Failed to load image: ./poses_dataset/Images/Goddess/127.json
# Failed to load image: ./poses_dataset/Images/Goddess/128.json
# Failed to load image: ./poses_dataset/Images/Goddess/129.json
# Failed to load image: ./poses_dataset/Images/Goddess/13.json
# Failed to load image: ./poses_dataset/Images/Goddess/130.json
# Failed to load image: ./poses_dataset/Images/Goddess/131.json
# Failed to load image: ./poses_dataset/Images/Goddess/132.json
# Failed to load image: ./poses_dataset/Images/Goddess/133.json
# Failed to load image: ./poses_dataset/Images/Goddess/134.json
# Failed to load image: ./poses_dataset/Images/Goddess/135.json
# Failed to load image: ./poses_dataset/Images/Goddess/14.json
# Failed to load image: ./poses_dataset/Images/Goddess/15.json
# Failed to load image: ./poses_dataset/Images/Goddess/16.json
# Failed to load image: ./poses_dataset/Images/Goddess/17.json
# Failed to load image: ./poses_dataset/Images/Goddess/18.json
# Failed to load image: ./poses_dataset/Images/Goddess/19.json
# Failed to load image: ./poses_dataset/Images/Goddess/2.json
# Failed to load image: ./poses_dataset/Images/Goddess/20.json
# Failed to load image: ./poses_dataset/Images/Goddess/21.json
# Failed to load image: ./poses_dataset/Images/Goddess/22.json
# Failed to load image: ./poses_dataset/Images/Goddess/23.json
# Failed to load image: ./poses_dataset/Images/Goddess/24.json
# Failed to load image: ./poses_dataset/Images/Goddess/25.json
# Failed to load image: ./poses_dataset/Images/Goddess/26.json
# Failed to load image: ./poses_dataset/Images/Goddess/27.json
# Failed to load image: ./poses_dataset/Images/Goddess/28.json
# Failed to load image: ./poses_dataset/Images/Goddess/29.json
# Failed to load image: ./poses_dataset/Images/Goddess/3.json
# Failed to load image: ./poses_dataset/Images/Goddess/30.json
# Failed to load image: ./poses_dataset/Images/Goddess/31.json
# Failed to load image: ./poses_dataset/Images/Goddess/32.json
# Failed to load image: ./poses_dataset/Images/Goddess/33.json
# Failed to load image: ./poses_dataset/Images/Goddess/34.json
# Failed to load image: ./poses_dataset/Images/Goddess/35.json
# Failed to load image: ./poses_dataset/Images/Goddess/36.json
# Failed to load image: ./poses_dataset/Images/Goddess/37.json
# Failed to load image: ./poses_dataset/Images/Goddess/38.json
# Failed to load image: ./poses_dataset/Images/Goddess/39.json
# Failed to load image: ./poses_dataset/Images/Goddess/4.json
# Failed to load image: ./poses_dataset/Images/Goddess/40.json
# Failed to load image: ./poses_dataset/Images/Goddess/41.json
# Failed to load image: ./poses_dataset/Images/Goddess/42.json
# Failed to load image: ./poses_dataset/Images/Goddess/43.json
# Failed to load image: ./poses_dataset/Images/Goddess/44.json
# Failed to load image: ./poses_dataset/Images/Goddess/45.json
# No pose landmarks detected: ./poses_dataset/Images/Goddess/46 - Copy.jpg
# No pose landmarks detected: ./poses_dataset/Images/Goddess/46.jpg
# Failed to load image: ./poses_dataset/Images/Goddess/46.json
# Failed to load image: ./poses_dataset/Images/Goddess/47.json
# Failed to load image: ./poses_dataset/Images/Goddess/48.json
# Failed to load image: ./poses_dataset/Images/Goddess/49.json
# Failed to load image: ./poses_dataset/Images/Goddess/5.json
# Failed to load image: ./poses_dataset/Images/Goddess/50.json
# Failed to load image: ./poses_dataset/Images/Goddess/51.json
# Failed to load image: ./poses_dataset/Images/Goddess/52.json
# Failed to load image: ./poses_dataset/Images/Goddess/53.json
# Failed to load image: ./poses_dataset/Images/Goddess/54.json
# Failed to load image: ./poses_dataset/Images/Goddess/55.json
# Failed to load image: ./poses_dataset/Images/Goddess/56.json
# Failed to load image: ./poses_dataset/Images/Goddess/57.json
# Failed to load image: ./poses_dataset/Images/Goddess/58.json
# Failed to load image: ./poses_dataset/Images/Goddess/59.json
# Failed to load image: ./poses_dataset/Images/Goddess/6.json
# Failed to load image: ./poses_dataset/Images/Goddess/60.json
# Failed to load image: ./poses_dataset/Images/Goddess/61.json
# Failed to load image: ./poses_dataset/Images/Goddess/62.json
# Failed to load image: ./poses_dataset/Images/Goddess/63.json
# Failed to load image: ./poses_dataset/Images/Goddess/64.json
# Failed to load image: ./poses_dataset/Images/Goddess/65.json
# Failed to load image: ./poses_dataset/Images/Goddess/66.json
# Failed to load image: ./poses_dataset/Images/Goddess/67.json
# Failed to load image: ./poses_dataset/Images/Goddess/68.json
# Failed to load image: ./poses_dataset/Images/Goddess/69.json
# Failed to load image: ./poses_dataset/Images/Goddess/7.json
# Failed to load image: ./poses_dataset/Images/Goddess/70.json
# Failed to load image: ./poses_dataset/Images/Goddess/71.json
# Failed to load image: ./poses_dataset/Images/Goddess/72.json
# Failed to load image: ./poses_dataset/Images/Goddess/73.json
# Failed to load image: ./poses_dataset/Images/Goddess/74.json
# Failed to load image: ./poses_dataset/Images/Goddess/75.json
# Failed to load image: ./poses_dataset/Images/Goddess/76.json
# Failed to load image: ./poses_dataset/Images/Goddess/77.json
# Failed to load image: ./poses_dataset/Images/Goddess/78.json
# Failed to load image: ./poses_dataset/Images/Goddess/79.json
# Failed to load image: ./poses_dataset/Images/Goddess/8.json
# Failed to load image: ./poses_dataset/Images/Goddess/80.json
# Failed to load image: ./poses_dataset/Images/Goddess/81.json
# Failed to load image: ./poses_dataset/Images/Goddess/82.json
# Failed to load image: ./poses_dataset/Images/Goddess/83.json
# Failed to load image: ./poses_dataset/Images/Goddess/84.json
# Failed to load image: ./poses_dataset/Images/Goddess/85.json
# Failed to load image: ./poses_dataset/Images/Goddess/86.json
# Failed to load image: ./poses_dataset/Images/Goddess/87.json
# Failed to load image: ./poses_dataset/Images/Goddess/88.json
# Failed to load image: ./poses_dataset/Images/Goddess/89.json
# Failed to load image: ./poses_dataset/Images/Goddess/9.json
# Failed to load image: ./poses_dataset/Images/Goddess/90.json
# Failed to load image: ./poses_dataset/Images/Goddess/91.json
# Failed to load image: ./poses_dataset/Images/Goddess/92.json
# Failed to load image: ./poses_dataset/Images/Goddess/93.json
# Failed to load image: ./poses_dataset/Images/Goddess/94.json
# Failed to load image: ./poses_dataset/Images/Goddess/95.json
# Failed to load image: ./poses_dataset/Images/Goddess/96.json
# Failed to load image: ./poses_dataset/Images/Goddess/97.json
# Failed to load image: ./poses_dataset/Images/Goddess/98.json
# Failed to load image: ./poses_dataset/Images/Goddess/99.json
# Pose data successfully saved to './csv_files/poses_data_pose.csv'
